# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1, 2, 3,4 ,5,6,7,8,9]
y = [12, 34, 54, 2, 12, 21, 9, 87, 46]

# %%
plt.plot(x,y)

# %%
plt.xlabel('Day')
plt.ylabel('Temp')
plt.title('Weather')
plt.plot(x,y, color='red', linewidth = 5)
